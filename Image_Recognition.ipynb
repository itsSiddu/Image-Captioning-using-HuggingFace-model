# %%
import warnings,logging
warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
! pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 20.1 MB/s eta 0:00:00

# %%
from transformers import pipeline

# %%
caption = pipeline('image-to-text')

# %%
# !wget -O img2text.jpg 'https://t3.ftcdn.net/jpg/03/73/95/24/360_F_373952412_a7VTdxI4hp0tsWmkWeCcxwAuyi3PpVMF.jpg'

from IPython.display import Image
Image(filename='img2text.jpg')
# Out:
# --2023-04-12 14:56:23--  https://t3.ftcdn.net/jpg/03/73/95/24/360_F_373952412_a7VTdxI4hp0tsWmkWeCcxwAuyi3PpVMF.jpg
# Resolving t3.ftcdn.net (t3.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to t3.ftcdn.net (t3.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49027 (48K) [image/jpeg]
# Saving to: ‘img2text.jpg’
#
# img2text.jpg        100%[===================>]  47.88K  --.-KB/s    in 0.01s
#
# 2023-04-12 14:56:23 (3.81 MB/s) - ‘img2text.jpg’ saved [49027/49027]

# %%
caption('img2text.jpg')
# Out:
# [{'generated_text': 'a woman holding a camera in her right hand '}]
